# %%
import requests
import json

response = requests.post(
  url="https://openrouter.ai/api/v1/chat/completions",
  headers={
    "Authorization": "Bearer your_openAI_API_KEY",
    "Content-Type": "application/json",
    "HTTP-Referer": "<YOUR_SITE_URL>", # Optional. Site URL for rankings on openrouter.ai.
    "X-Title": "<YOUR_SITE_NAME>", # Optional. Site title for rankings on openrouter.ai.
  },
  data=json.dumps({
    "model": "meta-llama/llama-4-maverick",
    "messages": [
      {
        "role": "user",
        "content": [
          {
            "type": "text",
            "text": "What is in this image?"
          },
          {
            "type": "image_url",
            "image_url": {
              "url": "https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg/2560px-Gfp-wisconsin-madison-the-nature-boardwalk.jpg"
            }
          }
        ]
      }
    ]
  })
)

# %%
print(response.content)
# Out:
# b'\n         \n\n         \n\n         \n\n         \n\n         \n\n         \n\n         \n\n         \n\n         \n\n         \n{"id":"gen-1764136404-jmaYPmlvOltQ8uJDKtPz","provider":"Novita","model":"meta-llama/llama-4-maverick","object":"chat.completion","created":1764136404,"choices":[{"logprobs":null,"finish_reason":"stop","native_finish_reason":"stop","index":0,"message":{"role":"assistant","content":"The image depicts a serene and idyllic scene of a wooden boardwalk through a marshy field on a sunny day.\\n\\n*   The boardwalk is made of weathered wooden planks, with a railing on either side constructed from wooden logs. \\n    *   It stretches from the foreground to the background, disappearing into the distance.\\n    *   The boardwalk is flanked by tall grasses and reeds that reach up to the height of the walkway.\\n*   The surrounding landscape is characterized by lush greenery, with trees visible in the distance.\\n    *   The sky above is a brilliant blue, dotted with
# ...

# %%
import requests
import json

response1 = requests.post(
  url="https://openrouter.ai/api/v1/chat/completions",
  headers={
    "Authorization": "Bearer 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",
    "Content-Type": "application/json",
    "HTTP-Referer": "<YOUR_SITE_URL>", # Optional. Site URL for rankings on openrouter.ai.
    "X-Title": "<YOUR_SITE_NAME>", # Optional. Site title for rankings on openrouter.ai.
  },
  data=json.dumps({
    "model": "google/gemini-2.5-flash",
    "messages": [
      {
        "role": "user",
        "content": [
          {
            "type": "text",
            "text": "What is in this image?"
          },
          {
            "type": "image_url",
            "image_url": {
              "url": "https://www.bing.com/ck/a?!&&p=37007398069471c322f9ed3dceae1949b4ce8f59d075a3193a4da461921f363dJmltdHM9MTc2NDAyODgwMA&ptn=3&ver=2&hsh=4&fclid=2383ba91-e02a-6901-1a29-af48e18768e4&u=a1L2ltYWdlcy9zZWFyY2g_cT1wZWFjb2NrK2ltYWdlJmlkPTYwQkZBQjIwNkUwOUUxQzBGRENDOUUxM0NCN0IzNDVEQTk3NzIwQTgmRk9STT1JQUNGSVI&ntb=1"
            }
          }
        ]
      }
    ]
  })
)

# %%
print(response1.content)
# Out:
# b'{"error":{"message":"This request requires more credits, or fewer max_tokens. You requested up to 64000 tokens, but can only afford 15964. To increase, visit https://openrouter.ai/settings/credits and upgrade to a paid account","code":402,"metadata":{"provider_name":null}},"user_id":"user_360FN7IhnYA6apiM7MtkiFqLIXL"}'
